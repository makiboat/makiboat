# %%
import pandas as pd

# %%
citibike01=pd.read_csv("citibike202001_1000.csv")

# %%
citibike02=pd.read_csv("citibike202002_1000.csv")

# %%
citibike03=pd.read_csv("citibike202003_1000.csv")

# %%
citibike04=pd.read_csv("citibike202004_1000.csv")
citibike05=pd.read_csv("citibike202005_1000.csv")
citibike06=pd.read_csv("citibike202006_1000.csv")
citibike07=pd.read_csv("citibike202007_1000.csv")
citibike08=pd.read_csv("citibike202008_1000.csv")
citibike09=pd.read_csv("citibike202009_1000.csv")
citibike10=pd.read_csv("citibike202010_1000.csv")
citibike11=pd.read_csv("citibike202011_1000.csv")
citibike12=pd.read_csv("citibike202012_1000.csv")

# %%
bigdata = pd.concat([citibike01, citibike02,citibike03,citibike04,citibike05,citibike06,citibike07,citibike08,citibike09,citibike10,citibike11,citibike12], ignore_index=True, sort=False)

# %%
bigdata
# Out:
#        tripduration starttime stoptime  start station id  \
# 0               900   53:08.4  08:09.0               522
# 1              1187   19:33.0  39:20.7               529
# 2               512   23:08.7  31:41.3              3178
# 3               799   37:43.5  51:02.7              3755
# 4               650   16:48.0  27:38.4               442
# ...             ...       ...      ...               ...
# 11995           539   39:49.7  48:49.2              4072
# 11996           711   04:59.7  16:51.1               515
# 11997           468   12:50.7  20:39.3              3620
# 11998           651   35:12.7  46:04.1              3894
# 11999           536   47:46.5  56:42.6               500
#
#                 start station name  start station latitude  \
# 0          E 51 St & Lexington Ave               40.757148
# 1                  W 42 St & 8 Ave               40.757570
# 2           Riverside Dr & W 78 St               40.784145
# ...

# %%
bigdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             12000 non-null  int64
#  1   starttime                12000 non-null  object
#  2   stoptime                 12000 non-null  object
#  3   start station id         12000 non-null  int64
#  4   start station name       12000 non-null  object
#  5   start station latitude   12000 non-null  float64
#  6   start station longitude  12000 non-null  float64
#  7   end station id           12000 non-null  int64
#  8   end station name         12000 non-null  object
#  9   end station latitude     12000 non-null  float64
#  10  end station longitude    12000 non-null  float64
#  11  bikeid                   12000 non-null  int64
#  12  usertype                 12000 non-null  object
#  13  birth year               12000 non-null  int64
# ...

# %%
bigdata.to_csv("citibike2020.csv")
